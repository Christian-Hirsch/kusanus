# %% [markdown]
# # Katzen gegen Hunde -- Lineares Modell

# %% [markdown]
# In einem frueheren Notebook haben wir den magischen ``finetune``-Befehl benutzt um aus VGG16 einen Classifier fuer Cats vs. Dogs zu bauen. In diesem Notebook loesen wir diesen Zauber schrittweise auf.

# %% [markdown]
# # 1. Schritt: Logistische Regression auf VGG-features

# %% [markdown]
# Im ersten Schritt berechnen wir mit Hilfe des Standard VGG-Classifiers die Wahrscheinlichkeiten fuer die 1000 Imagenet-Kategorien. Darauf setzen wir ein logistisches Regressionsmodell auf.

# %% [markdown]
# Zunaechst setzen wir Generatoren fuer Trainings- und Testdaten auf.

# %%
import sys
import numpy as np
sys.path.insert(0, '../scripts')
import nn_helper

from nn_helper import get_batches, finetune 

from tensorflow.contrib.keras.python.keras.applications.vgg16 import  VGG16
from tensorflow.contrib.keras.python.keras.layers import Dense, Flatten
from tensorflow.contrib.keras.python.keras.models import Sequential, Model
from tensorflow.contrib.keras.python.keras.optimizers import Adam

#############################################
############FILE PATHS
#############################################
ROOT = '../../deepLearning/data/processed/cats_vs_dogs'
FEATURE_PATH = '../../deepLearning/features/cats_vs_dogs'


#############################################
############DNN PARAMETERS
#############################################
LR0 = 1e-4
BATCH_SIZE_SMALL = 8
BATCH_SIZE = 64
SEED = 42

def batch_class(folder): 
    #retrieve images in batches
    np.random.seed(SEED)
    batches = get_batches(folder, batch_size = BATCH_SIZE_SMALL, shuffle = True, seed = SEED) 
    
    #get filenames corresponding to the batches
    np.random.seed(SEED)    
    fns = np.random.permutation(batches.filenames)
    #convert to binary vector
    y = [1 * (fn[:3] == 'dog') for fn in fns]
    return batches, y
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Jetzt erzeugen wir die  VGG16 Vorhersagen.

# %%
# %%time

vgg = VGG16(weights='imagenet')
[t_batch_classes, v_batch_classes]  = [batch_class('{}/{}'.format(ROOT, tv)) for tv in ['train', 'valid']]
[t_preds, v_preds]=[vgg.predict_generator(batches, steps = int(batches.samples/batches.batch_size))
                    for batches, _ in [t_batch_classes, v_batch_classes]]
# Out:
# Found 24000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# CPU times: user 4.32 s, sys: 756 ms, total: 5.07 s
# Wall time: 3.57 s

# %% [markdown]
# Alternativ laden wir die Vorhersagen von der Platte.

# %%
[t_preds, v_preds] = [np.load('{}/vgg_features_{}.npy'.format(FEATURE_PATH, tv)) for tv in ['train','valid']]

# %% [markdown]
# Jetzt definieren wir ein lineares Modell in Keras

# %%
layers = [Dense(0, activation = 'sigmoid', input_shape = (0,))] 
model = Sequential(layers)

# %% [markdown]
# Jetzt spezifizieren wir die Verlustfunktion und die Optimizierungsmethodee

# %%
LEARN_RATE = 1e-3
model.compile(loss = 'None', optimizer = Adam(LEARN_RATE), metrics= ['None'])

# %% [markdown]
# Letztendlich fitten wir das Modell auf die Input-Daten von VGG.

# %%
model.fit(None, None, validation_data = None, epochs = 30)

# %% [markdown]
# In der Tat erhalten wir bereits mit weniger Daten ein gutes Modell

# %%
#Trainiere auf 100 Beispieldaten!
# Out:
# Train on 100 samples, validate on 1000 samples
# Epoch 1/100
# 100/100 [==============================] - 0s - loss: 0.6931 - acc: 0.5500 - val_loss: 0.6931 - val_acc: 0.5310
# Epoch 2/100
# 100/100 [==============================] - 0s - loss: 0.6923 - acc: 0.5500 - val_loss: 0.6924 - val_acc: 0.5530
# Epoch 3/100
# 100/100 [==============================] - 0s - loss: 0.6915 - acc: 0.5700 - val_loss: 0.6918 - val_acc: 0.5770
# Epoch 4/100
# 100/100 [==============================] - 0s - loss: 0.6908 - acc: 0.6000 - val_loss: 0.6912 - val_acc: 0.5930
# Epoch 5/100
# 100/100 [==============================] - 0s - loss: 0.6900 - acc: 0.6100 - val_loss: 0.6905 - val_acc: 0.6040
# Epoch 6/100
# 100/100 [==============================] - 0s - loss: 0.6893 - acc: 0.6200 - val_loss: 0.6899 - val_acc: 0.6190
# Epoch 7/100
# 100/100 [==============================] - 0s - loss: 0.6885 - acc: 0.6300 - val_loss: 0.6893 - val_acc: 0.6290
# Epoch 8/100
# 100/100 [==============================] - 0s - loss: 0.6878 - acc: 0.6800 - val_loss: 0.6887 - val_acc: 0.6460
# Epoch 9/100
# 100/100 [==============================] - 0s - loss: 0.6870 - acc: 0.7000 - val_loss: 0.6880 - val_acc: 0.6600
# Epoch 10/100
# 100/100 [==============================] - 0s - loss: 0.6863 - acc: 0.7200 - val_loss: 0.6874 - val_acc: 0.6850
# Epoch 11/100
# 100/100 [==============================] - 0s - loss: 0.6855 - acc: 0.7300 - val_loss: 0.6868 - val_acc: 0.6900
# Epoch 12/100
# 100/100 [==============================] - 0s - loss: 0.6848 - acc: 0.7400 - val_loss: 0.6861 - val_acc: 0.7100
# Epoch 13/100
# 100/100 [==============================] - 0s - loss: 0.6840 - acc: 0.7500 - val_loss: 0.6855 - val_acc: 0.7270
# Epoch 14/100
# 100/100 [==============================] - 0s - loss: 0.6833 - acc: 0.7600 - val_loss: 0.6849 - val_acc: 0.7420
# Epoch 15/100
# 100/100 [==============================] - 0s - loss: 0.6826 - acc: 0.7700 - val_loss: 0.6843 - val_acc: 0.7550
# Epoch 16/100
# 100/100 [==============================] - 0s - loss: 0.6818 - acc: 0.7900 - val_loss: 0.6836 - val_acc: 0.7670
# Epoch 17/100
# 100/100 [==============================] - 0s - loss: 0.6811 - acc: 0.8000 - val_loss: 0.6830 - val_acc: 0.7730
# Epoch 18/100
# 100/100 [==============================] - 0s - loss: 0.6804 - acc: 0.8200 - val_loss: 0.6824 - val_acc: 0.7830
# Epoch 19/100
# 100/100 [==============================] - 0s - loss: 0.6796 - acc: 0.8300 - val_loss: 0.6818 - val_acc: 0.7940
# Epoch 20/100
# 100/100 [==============================] - 0s - loss: 0.6789 - acc: 0.8500 - val_loss: 0.6811 - val_acc: 0.8030
# Epoch 21/100
# 100/100 [==============================] - 0s - loss: 0.6782 - acc: 0.8600 - val_loss: 0.6805 - val_acc: 0.8130
# Epoch 22/100
# 100/100 [==============================] - 0s - loss: 0.6775 - acc: 0.8700 - val_loss: 0.6799 - val_acc: 0.8180
# Epoch 23/100
# 100/100 [==============================] - 0s - loss: 0.6767 - acc: 0.8800 - val_loss: 0.6793 - val_acc: 0.8290
# Epoch 24/100
# 100/100 [==============================] - 0s - loss: 0.6760 - acc: 0.9000 - val_loss: 0.6787 - val_acc: 0.8360
# Epoch 25/100
# 100/100 [==============================] - 0s - loss: 0.6753 - acc: 0.9100 - val_loss: 0.6781 - val_acc: 0.8410
# Epoch 26/100
# 100/100 [==============================] - 0s - loss: 0.6745 - acc: 0.9200 - val_loss: 0.6775 - val_acc: 0.8440
# Epoch 27/100
# 100/100 [==============================] - 0s - loss: 0.6738 - acc: 0.9300 - val_loss: 0.6769 - val_acc: 0.8500
# Epoch 28/100
# 100/100 [==============================] - 0s - loss: 0.6731 - acc: 0.9300 - val_loss: 0.6762 - val_acc: 0.8550
# Epoch 29/100
# 100/100 [==============================] - 0s - loss: 0.6724 - acc: 0.9600 - val_loss: 0.6756 - val_acc: 0.8590
# Epoch 30/100
# 100/100 [==============================] - 0s - loss: 0.6717 - acc: 0.9600 - val_loss: 0.6750 - val_acc: 0.8640
# Epoch 31/100
# 100/100 [==============================] - 0s - loss: 0.6709 - acc: 0.9600 - val_loss: 0.6744 - val_acc: 0.8680
# Epoch 32/100
# 100/100 [==============================] - 0s - loss: 0.6702 - acc: 0.9600 - val_loss: 0.6738 - val_acc: 0.8700
# Epoch 33/100
# 100/100 [==============================] - 0s - loss: 0.6695 - acc: 0.9600 - val_loss: 0.6732 - val_acc: 0.8710
# Epoch 34/100
# 100/100 [==============================] - 0s - loss: 0.6688 - acc: 0.9600 - val_loss: 0.6726 - val_acc: 0.8760
# Epoch 35/100
# 100/100 [==============================] - 0s - loss: 0.6680 - acc: 0.9600 - val_loss: 0.6720 - val_acc: 0.8810
# Epoch 36/100
# 100/100 [==============================] - 0s - loss: 0.6673 - acc: 0.9700 - val_loss: 0.6714 - val_acc: 0.8860
# Epoch 37/100
# 100/100 [==============================] - 0s - loss: 0.6666 - acc: 0.9700 - val_loss: 0.6707 - val_acc: 0.8880
# Epoch 38/100
# 100/100 [==============================] - 0s - loss: 0.6659 - acc: 0.9700 - val_loss: 0.6701 - val_acc: 0.8900
# Epoch 39/100
# 100/100 [==============================] - 0s - loss: 0.6652 - acc: 0.9700 - val_loss: 0.6695 - val_acc: 0.8910
# Epoch 40/100
# 100/100 [==============================] - 0s - loss: 0.6645 - acc: 0.9700 - val_loss: 0.6689 - val_acc: 0.8950
# Epoch 41/100
# 100/100 [==============================] - 0s - loss: 0.6638 - acc: 0.9800 - val_loss: 0.6683 - val_acc: 0.8960
# Epoch 42/100
# 100/100 [==============================] - 0s - loss: 0.6631 - acc: 0.9800 - val_loss: 0.6677 - val_acc: 0.8960
# Epoch 43/100
# 100/100 [==============================] - 0s - loss: 0.6623 - acc: 0.9800 - val_loss: 0.6671 - val_acc: 0.8970
# Epoch 44/100
# 100/100 [==============================] - 0s - loss: 0.6616 - acc: 0.9800 - val_loss: 0.6665 - val_acc: 0.8960
# Epoch 45/100
# 100/100 [==============================] - 0s - loss: 0.6609 - acc: 0.9800 - val_loss: 0.6659 - val_acc: 0.8960
# Epoch 46/100
# 100/100 [==============================] - 0s - loss: 0.6602 - acc: 0.9800 - val_loss: 0.6653 - val_acc: 0.8960
# Epoch 47/100
# 100/100 [==============================] - 0s - loss: 0.6595 - acc: 0.9800 - val_loss: 0.6647 - val_acc: 0.8960
# Epoch 48/100
# 100/100 [==============================] - 0s - loss: 0.6588 - acc: 0.9800 - val_loss: 0.6641 - val_acc: 0.8960
# Epoch 49/100
# 100/100 [==============================] - 0s - loss: 0.6581 - acc: 0.9800 - val_loss: 0.6635 - val_acc: 0.8960
# Epoch 50/100
# 100/100 [==============================] - 0s - loss: 0.6574 - acc: 0.9800 - val_loss: 0.6629 - val_acc: 0.8950
# Epoch 51/100
# 100/100 [==============================] - 0s - loss: 0.6567 - acc: 0.9800 - val_loss: 0.6623 - val_acc: 0.8960
# Epoch 52/100
# 100/100 [==============================] - 0s - loss: 0.6560 - acc: 0.9800 - val_loss: 0.6618 - val_acc: 0.8960
# Epoch 53/100
# 100/100 [==============================] - 0s - loss: 0.6553 - acc: 0.9800 - val_loss: 0.6612 - val_acc: 0.8950
# Epoch 54/100
# 100/100 [==============================] - 0s - loss: 0.6546 - acc: 0.9800 - val_loss: 0.6606 - val_acc: 0.8960
# Epoch 55/100
# 100/100 [==============================] - 0s - loss: 0.6539 - acc: 0.9800 - val_loss: 0.6600 - val_acc: 0.8950
# Epoch 56/100
# 100/100 [==============================] - 0s - loss: 0.6532 - acc: 0.9900 - val_loss: 0.6594 - val_acc: 0.8950
# Epoch 57/100
# 100/100 [==============================] - 0s - loss: 0.6525 - acc: 0.9900 - val_loss: 0.6588 - val_acc: 0.8950
# Epoch 58/100
# 100/100 [==============================] - 0s - loss: 0.6518 - acc: 0.9900 - val_loss: 0.6582 - val_acc: 0.8950
# Epoch 59/100
# 100/100 [==============================] - 0s - loss: 0.6511 - acc: 0.9900 - val_loss: 0.6576 - val_acc: 0.8950
# Epoch 60/100
# 100/100 [==============================] - 0s - loss: 0.6504 - acc: 0.9900 - val_loss: 0.6570 - val_acc: 0.8960
# Epoch 61/100
# 100/100 [==============================] - 0s - loss: 0.6497 - acc: 0.9900 - val_loss: 0.6564 - val_acc: 0.8960
# Epoch 62/100
# 100/100 [==============================] - 0s - loss: 0.6490 - acc: 0.9900 - val_loss: 0.6558 - val_acc: 0.8970
# Epoch 63/100
# 100/100 [==============================] - 0s - loss: 0.6483 - acc: 0.9900 - val_loss: 0.6552 - val_acc: 0.8980
# Epoch 64/100
# 100/100 [==============================] - 0s - loss: 0.6476 - acc: 0.9900 - val_loss: 0.6546 - val_acc: 0.8970
# Epoch 65/100
# 100/100 [==============================] - 0s - loss: 0.6469 - acc: 0.9900 - val_loss: 0.6541 - val_acc: 0.8980
# Epoch 66/100
# 100/100 [==============================] - 0s - loss: 0.6462 - acc: 0.9900 - val_loss: 0.6535 - val_acc: 0.8980
# Epoch 67/100
# 100/100 [==============================] - 0s - loss: 0.6455 - acc: 0.9900 - val_loss: 0.6529 - val_acc: 0.8980
# Epoch 68/100
# 100/100 [==============================] - 0s - loss: 0.6448 - acc: 0.9900 - val_loss: 0.6523 - val_acc: 0.8980
# Epoch 69/100
# 100/100 [==============================] - 0s - loss: 0.6441 - acc: 0.9900 - val_loss: 0.6517 - val_acc: 0.8980
# Epoch 70/100
# 100/100 [==============================] - 0s - loss: 0.6434 - acc: 0.9900 - val_loss: 0.6512 - val_acc: 0.8980
# Epoch 71/100
# 100/100 [==============================] - 0s - loss: 0.6428 - acc: 0.9900 - val_loss: 0.6506 - val_acc: 0.8980
# Epoch 72/100
# 100/100 [==============================] - 0s - loss: 0.6421 - acc: 0.9900 - val_loss: 0.6500 - val_acc: 0.8980
# Epoch 73/100
# 100/100 [==============================] - 0s - loss: 0.6414 - acc: 0.9900 - val_loss: 0.6494 - val_acc: 0.8980
# Epoch 74/100
# 100/100 [==============================] - 0s - loss: 0.6407 - acc: 0.9900 - val_loss: 0.6488 - val_acc: 0.8980
# Epoch 75/100
# 100/100 [==============================] - 0s - loss: 0.6400 - acc: 0.9900 - val_loss: 0.6483 - val_acc: 0.8980
# Epoch 76/100
# 100/100 [==============================] - 0s - loss: 0.6393 - acc: 0.9900 - val_loss: 0.6477 - val_acc: 0.8990
# Epoch 77/100
# 100/100 [==============================] - 0s - loss: 0.6387 - acc: 0.9900 - val_loss: 0.6471 - val_acc: 0.9000
# Epoch 78/100
# 100/100 [==============================] - 0s - loss: 0.6380 - acc: 0.9900 - val_loss: 0.6466 - val_acc: 0.9000
# Epoch 79/100
# 100/100 [==============================] - 0s - loss: 0.6373 - acc: 0.9900 - val_loss: 0.6460 - val_acc: 0.9000
# Epoch 80/100
# 100/100 [==============================] - 0s - loss: 0.6366 - acc: 0.9900 - val_loss: 0.6454 - val_acc: 0.9000
# Epoch 81/100
# 100/100 [==============================] - 0s - loss: 0.6359 - acc: 0.9900 - val_loss: 0.6448 - val_acc: 0.9010
# Epoch 82/100
# 100/100 [==============================] - 0s - loss: 0.6353 - acc: 0.9900 - val_loss: 0.6443 - val_acc: 0.9010
# Epoch 83/100
# 100/100 [==============================] - 0s - loss: 0.6346 - acc: 0.9900 - val_loss: 0.6437 - val_acc: 0.9010
# Epoch 84/100
# 100/100 [==============================] - 0s - loss: 0.6339 - acc: 0.9900 - val_loss: 0.6431 - val_acc: 0.9000
# Epoch 85/100
# 100/100 [==============================] - 0s - loss: 0.6332 - acc: 0.9900 - val_loss: 0.6425 - val_acc: 0.9000
# Epoch 86/100
# 100/100 [==============================] - 0s - loss: 0.6325 - acc: 0.9900 - val_loss: 0.6420 - val_acc: 0.9000
# Epoch 87/100
# 100/100 [==============================] - 0s - loss: 0.6319 - acc: 0.9900 - val_loss: 0.6414 - val_acc: 0.9010
# Epoch 88/100
# 100/100 [==============================] - 0s - loss: 0.6312 - acc: 0.9900 - val_loss: 0.6409 - val_acc: 0.9020
# Epoch 89/100
# 100/100 [==============================] - 0s - loss: 0.6305 - acc: 0.9900 - val_loss: 0.6403 - val_acc: 0.9020
# Epoch 90/100
# 100/100 [==============================] - 0s - loss: 0.6299 - acc: 0.9900 - val_loss: 0.6397 - val_acc: 0.9010
# Epoch 91/100
# 100/100 [==============================] - 0s - loss: 0.6292 - acc: 0.9900 - val_loss: 0.6392 - val_acc: 0.9010
# Epoch 92/100
# 100/100 [==============================] - 0s - loss: 0.6285 - acc: 0.9900 - val_loss: 0.6386 - val_acc: 0.9010
# Epoch 93/100
# 100/100 [==============================] - 0s - loss: 0.6279 - acc: 0.9900 - val_loss: 0.6381 - val_acc: 0.9010
# Epoch 94/100
# 100/100 [==============================] - 0s - loss: 0.6272 - acc: 0.9900 - val_loss: 0.6375 - val_acc: 0.9010
# Epoch 95/100
# 100/100 [==============================] - 0s - loss: 0.6265 - acc: 0.9900 - val_loss: 0.6370 - val_acc: 0.9000
# Epoch 96/100
# 100/100 [==============================] - 0s - loss: 0.6259 - acc: 0.9900 - val_loss: 0.6364 - val_acc: 0.9000
# Epoch 97/100
# 100/100 [==============================] - 0s - loss: 0.6252 - acc: 0.9900 - val_loss: 0.6358 - val_acc: 0.8990
# Epoch 98/100
# 100/100 [==============================] - 0s - loss: 0.6245 - acc: 0.9900 - val_loss: 0.6353 - val_acc: 0.9000
# Epoch 99/100
# 100/100 [==============================] - 0s - loss: 0.6239 - acc: 0.9900 - val_loss: 0.6347 - val_acc: 0.9000
# Epoch 100/100
# 100/100 [==============================] - 0s - loss: 0.6232 - acc: 0.9900 - val_loss: 0.6342 - val_acc: 0.9000

# %% [markdown]
# ## 2. Schritt Finetune VGG16

# %% [markdown]
# Es zeigt sich, dass der letzte Layer von VGG16 gerade einer logistischen Regression entspricht. Wir entfernen diese Schicht und ersetzen sie durch unsere eigene.

# %%
vgg.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544.0
# Trainable params: 0.0
# Non-trainable params: 138,357,544.0
# _________________________________________________________________

# %% [markdown]
# Wir lassen die Gewichte in frueheren Layern unberuehrt.

# %%
for layer in vgg.layers: layer.trainable = False

# %% [markdown]
# Wir nehmen die Ausgabe des vorletzten outputs von VGG und fuegen ihn als Eingabe in unseren neuen Dense Layer.

# %%
x = vgg.layers[-0].output
x = Dense(None, activation='None')(x) 

model = Model(inputs = vgg.input, outputs = x)

# %% [markdown]
# Jetzt kompilieren wir das Modell

# %%
model.compile(None)

# %% [markdown]
# ... und wir fitten es!

# %%
model.fit_generator(None, None, epochs = 1)

# %% [markdown]
# ## Arbeiten mit den vorgefertigten features

# %% [markdown]
# Das ganze kann ein Weilchen dauern... Alternativ stellen wir die vorhersagen aus einem frueheren Run wieder her

# %%
vgg_conv_features =  [np.load('{}/vgg_conv_features_{}.npy'.format(FEATURE_PATH, tv)) 
                      for tv in ['train', 'valid']]

# %% [markdown]
# Wir laden auch die Dateinamen.

# %%
labels = [np.load('{}/vgg_features_names_{}.npy'.format(FEATURE_PATH, tv))
       for tv in ['train', 'valid']]

# %% [markdown]
# Dadurch koennen wir die Architektur deutlich vereinfachen

# %%
def create_model():
    return Sequential([
        Flatten(),
        Dense(),
        Dense(),
    ])

# %%
model = create_model()
model.compile()

# %%
model.fit()
# Out:
# Train on 24000 samples, validate on 1000 samples
# Epoch 1/5
# 24000/24000 [==============================] - 26s - loss: 0.2290 - acc: 0.9487 - val_loss: 0.0977 - val_acc: 0.9630
# Epoch 2/5
# 24000/24000 [==============================] - 26s - loss: 0.0352 - acc: 0.9874 - val_loss: 0.0848 - val_acc: 0.9750
# Epoch 3/5
#  - ETA: 19s - loss: 0.0095 - acc: 0.9978
# Epoch 4/5
# 24000/24000 [==============================] - 25s - loss: 0.0033 - acc: 0.9993 - val_loss: 0.1066 - val_acc: 0.9740
# Epoch 5/5
#  - ETA: 15s - loss: 0.0014 - acc: 0.9996
